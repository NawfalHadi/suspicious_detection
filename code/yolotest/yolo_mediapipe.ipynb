# %% [markdown]
# # Cropped Frame by Yolo, Pose Estimation by Mediapipe

# %%
import mediapipe as mp
from mediapipe.framework.formats import landmark_pb2

from ultralytics import YOLO
import numpy as np
import cv2

mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# --- Configuration ---
FIXED_SIZE = 640
model = YOLO("../../model/yolo/yolo12n.pt")

# %%
def cropped_frame(frame):
    results = model(frame, classes=[0])
    boxes = results[0].boxes
    plotted_frame = results[0].plot() 

    try:
        if len(boxes) > 0:
            # Get the bounding box coordinates for the first detected object
            x1, y1, x2, y2 = boxes.xyxy[0].cpu().numpy().astype(int)

            cropped_frame = frame[y1:y2, x1:x2]
            crop_h, crop_w = cropped_frame.shape[:2]

            # We want to fit the largest dimension (width or height) to the FIXED_SIZE
            scale = FIXED_SIZE / max(crop_w, crop_h)
            new_w = int(crop_w * scale)
            new_h = int(crop_h * scale)

            # Resize the cropped frame to the new dimensions
            resized_img = cv2.resize(cropped_frame, (new_w, new_h), interpolation=cv2.INTER_AREA)

            # Background frame, that are not filled with boxes
            final_frame = np.full((FIXED_SIZE, FIXED_SIZE, 3), 255, dtype=np.uint8)
            
            # dw and dh are the space left over after placing the image
            dw = FIXED_SIZE - new_w
            dh = FIXED_SIZE - new_h

            # Calculate the starting position (top-left corner) for centering
            top = dh // 2
            bottom = top + new_h
            left = dw // 2
            right = left + new_w

            final_frame[top:bottom, left:right] = resized_img

            return final_frame

        else:
            print("No objects detected in the image.")
    except Exception as e:
        print(f"Error processing frame: {e}")

# %%
cap = cv2.VideoCapture('../../assets/dump/celinguk.mp4')

if not cap.isOpened():
    print("Error opening video file")
else:
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            ret, frame = cap.read()
            if ret:
                frame_cropped = cropped_frame(frame)

                try:
                    # Start Code of mediapipe here
                    frames = cv2.cvtColor(frame_cropped, cv2. COLOR_BGR2RGB)
                    frames.flags.writeable = False
                    
                    results = holistic.process(frames)
                    frames.flags.writeable = True
                    frames = cv2.cvtColor(frame_cropped, cv2. COLOR_RGB2BGR)

                    # Get specific landmarks
                    nose = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.NOSE]
                    wrist_l = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.LEFT_WRIST]
                    elbow_l = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.LEFT_ELBOW]
                    wrist_r = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.RIGHT_WRIST]
                    elbow_r = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.RIGHT_ELBOW]

                    show_landmark_list = landmark_pb2.NormalizedLandmarkList()
                    show_landmark_list.landmark.extend([nose, wrist_l, wrist_r, elbow_l, elbow_r])

                    # Draw landmarks
                    for landmark in show_landmark_list.landmark:
                        x, y = int(landmark.x * frames.shape[1]), int(landmark.y * frames.shape[0])
                        cv2.circle(frames, (x, y), 5, (255, 0, 0), -1)

                    cv2.imshow('Video', frames)
                except Exception as e:
                    print(f"Error displaying frame: {e}")
                
                
                if cv2.waitKey(5) & 0xFF == ord('q'):
                    break
            else:
                break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1760531617.687201     924 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1760531617.708447   64979 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.2), renderer: llvmpipe (LLVM 20.1.2, 256 bits)
# 0: 320x640 (no detections), 328.0ms
# Speed: 9.9ms preprocess, 328.0ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 69.1ms
# Speed: 5.9ms preprocess, 69.1ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 55.0ms
# Speed: 4.3ms preprocess, 55.0ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 50.4ms
# Speed: 5.7ms preprocess, 50.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 55.8ms
# Speed: 3.4ms preprocess, 55.8ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 42.5ms
# Speed: 4.9ms preprocess, 42.5ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 1 person, 54.0ms
# Speed: 3.4ms preprocess, 54.0ms inference, 10.4ms postprocess per image at shape (1, 3, 320, 640)
# W0000 00:00:1760531618.587337   64970 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531619.142547   64969 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531619.177230   64975 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531619.182932   64971 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531619.200046   64970 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531619.232605   64967 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531619.244732   64973 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531619.247171   64972 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 0: 320x640 1 person, 63.5ms
# Speed: 7.2ms preprocess, 63.5ms inference, 9.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 45.8ms
# Speed: 2.3ms preprocess, 45.8ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 34.0ms
# Speed: 3.1ms preprocess, 34.0ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.0ms
# Speed: 10.7ms preprocess, 36.0ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 58.2ms
# Speed: 3.1ms preprocess, 58.2ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 30.9ms
# Speed: 2.4ms preprocess, 30.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 46.1ms
# Speed: 3.5ms preprocess, 46.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 35.8ms
# Speed: 2.6ms preprocess, 35.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 37.7ms
# Speed: 2.5ms preprocess, 37.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 29.4ms
# Speed: 2.2ms preprocess, 29.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 32.9ms
# Speed: 2.8ms preprocess, 32.9ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 1 person, 38.7ms
# Speed: 2.0ms preprocess, 38.7ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.2ms
# Speed: 2.7ms preprocess, 32.2ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 50.6ms
# Speed: 4.2ms preprocess, 50.6ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 47.6ms
# Speed: 2.6ms preprocess, 47.6ms inference, 11.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.8ms
# Speed: 3.8ms preprocess, 29.8ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.2ms
# Speed: 2.8ms preprocess, 29.2ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.1ms
# Speed: 3.4ms preprocess, 36.1ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.6ms
# Speed: 2.4ms preprocess, 35.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.4ms
# Speed: 2.6ms preprocess, 26.4ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.9ms
# Speed: 3.2ms preprocess, 29.9ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 30.1ms
# Speed: 2.2ms preprocess, 30.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.3ms
# Speed: 3.9ms preprocess, 24.3ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.0ms
# Speed: 3.8ms preprocess, 23.0ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.3ms
# Speed: 3.1ms preprocess, 26.3ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.2ms
# Speed: 2.2ms preprocess, 23.2ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.9ms
# Speed: 2.9ms preprocess, 24.9ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.3ms
# Speed: 3.2ms preprocess, 27.3ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.8ms
# Speed: 2.3ms preprocess, 22.8ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 30.3ms
# Speed: 3.9ms preprocess, 30.3ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.5ms
# Speed: 2.9ms preprocess, 25.5ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.3ms
# Speed: 3.4ms preprocess, 24.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.2ms
# Speed: 2.6ms preprocess, 25.2ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.9ms
# Speed: 3.1ms preprocess, 24.9ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.7ms
# Speed: 2.6ms preprocess, 26.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.6ms
# Speed: 2.5ms preprocess, 25.6ms inference, 21.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.1ms
# Speed: 3.9ms preprocess, 29.1ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.5ms
# Speed: 3.4ms preprocess, 37.5ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.6ms
# Speed: 3.1ms preprocess, 20.6ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 48.5ms
# Speed: 2.9ms preprocess, 48.5ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.9ms
# Speed: 2.3ms preprocess, 31.9ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.5ms
# Speed: 2.3ms preprocess, 18.5ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.4ms
# Speed: 2.5ms preprocess, 19.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.2ms
# Speed: 2.9ms preprocess, 22.2ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.9ms
# Speed: 2.3ms preprocess, 19.9ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.9ms
# Speed: 3.1ms preprocess, 24.9ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.9ms
# Speed: 2.9ms preprocess, 36.9ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.4ms
# Speed: 2.2ms preprocess, 22.4ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.1ms
# Speed: 2.6ms preprocess, 20.1ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.2ms
# Speed: 3.2ms preprocess, 21.2ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.0ms
# Speed: 4.2ms preprocess, 23.0ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.8ms
# Speed: 3.3ms preprocess, 23.8ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 28.1ms
# Speed: 2.4ms preprocess, 28.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.0ms
# Speed: 3.1ms preprocess, 29.0ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.1ms
# Speed: 2.5ms preprocess, 29.1ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.0ms
# Speed: 2.5ms preprocess, 29.0ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 40.3ms
# Speed: 2.4ms preprocess, 40.3ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.1ms
# Speed: 2.3ms preprocess, 31.1ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.1ms
# Speed: 3.4ms preprocess, 27.1ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.9ms
# Speed: 2.7ms preprocess, 32.9ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.1ms
# Speed: 2.3ms preprocess, 23.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.5ms
# Speed: 2.2ms preprocess, 25.5ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.5ms
# Speed: 3.3ms preprocess, 26.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 41.1ms
# Speed: 2.5ms preprocess, 41.1ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.6ms
# Speed: 2.3ms preprocess, 26.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 28.0ms
# Speed: 2.6ms preprocess, 28.0ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.1ms
# Speed: 1.8ms preprocess, 37.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.9ms
# Speed: 2.9ms preprocess, 21.9ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.5ms
# Speed: 2.7ms preprocess, 20.5ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.7ms
# Speed: 2.4ms preprocess, 20.7ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.2ms
# Speed: 2.9ms preprocess, 35.2ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.5ms
# Speed: 2.5ms preprocess, 26.5ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.4ms
# Speed: 2.4ms preprocess, 24.4ms inference, 8.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 30.5ms
# Speed: 2.5ms preprocess, 30.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.5ms
# Speed: 2.0ms preprocess, 25.5ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.2ms
# Speed: 2.7ms preprocess, 24.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.4ms
# Speed: 2.3ms preprocess, 35.4ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 25.6ms
# Speed: 2.5ms preprocess, 25.6ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 27.1ms
# Speed: 2.8ms preprocess, 27.1ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 26.8ms
# Speed: 3.3ms preprocess, 26.8ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 34.4ms
# Speed: 2.9ms preprocess, 34.4ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 27.3ms
# Speed: 2.6ms preprocess, 27.3ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 25.5ms
# Speed: 2.7ms preprocess, 25.5ms inference, 10.6ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 37.0ms
# Speed: 2.2ms preprocess, 37.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 42.6ms
# Speed: 3.2ms preprocess, 42.6ms inference, 9.4ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 51.9ms
# Speed: 3.5ms preprocess, 51.9ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 22.8ms
# Speed: 3.8ms preprocess, 22.8ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 21.9ms
# Speed: 2.4ms preprocess, 21.9ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 20.7ms
# Speed: 2.3ms preprocess, 20.7ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 21.4ms
# Speed: 2.5ms preprocess, 21.4ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 24.5ms
# Speed: 2.6ms preprocess, 24.5ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 22.6ms
# Speed: 2.2ms preprocess, 22.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 26.3ms
# Speed: 3.3ms preprocess, 26.3ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 25.1ms
# Speed: 2.6ms preprocess, 25.1ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 24.5ms
# Speed: 3.2ms preprocess, 24.5ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 21.7ms
# Speed: 2.0ms preprocess, 21.7ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 28.5ms
# Speed: 2.9ms preprocess, 28.5ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 21.6ms
# Speed: 2.8ms preprocess, 21.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 22.7ms
# Speed: 2.6ms preprocess, 22.7ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.6ms
# Speed: 2.6ms preprocess, 24.6ms inference, 9.4ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 19.8ms
# Speed: 2.0ms preprocess, 19.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 39.8ms
# Speed: 2.1ms preprocess, 39.8ms inference, 8.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.2ms
# Speed: 2.4ms preprocess, 22.2ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 30.5ms
# Speed: 2.3ms preprocess, 30.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 25.8ms
# Speed: 2.1ms preprocess, 25.8ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 24.7ms
# Speed: 2.1ms preprocess, 24.7ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 320x640 1 person, 24.2ms
# Speed: 2.1ms preprocess, 24.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.5ms
# Speed: 2.8ms preprocess, 32.5ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.8ms
# Speed: 2.1ms preprocess, 19.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.5ms
# Speed: 3.4ms preprocess, 26.5ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.6ms
# Speed: 2.2ms preprocess, 18.6ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.4ms
# Speed: 2.3ms preprocess, 25.4ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.9ms
# Speed: 2.2ms preprocess, 19.9ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.3ms
# Speed: 2.2ms preprocess, 27.3ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.7ms
# Speed: 2.2ms preprocess, 20.7ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.0ms
# Speed: 2.3ms preprocess, 22.0ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.1ms
# Speed: 3.5ms preprocess, 25.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 30.6ms
# Speed: 3.4ms preprocess, 30.6ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 26.2ms
# Speed: 4.1ms preprocess, 26.2ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 34.9ms
# Speed: 2.5ms preprocess, 34.9ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 31.1ms
# Speed: 2.0ms preprocess, 31.1ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 37.6ms
# Speed: 2.0ms preprocess, 37.6ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 24.6ms
# Speed: 2.3ms preprocess, 24.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 31.1ms
# Speed: 2.8ms preprocess, 31.1ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.7ms
# Speed: 2.7ms preprocess, 31.7ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.3ms
# Speed: 2.9ms preprocess, 24.3ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.6ms
# Speed: 2.3ms preprocess, 23.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.5ms
# Speed: 2.6ms preprocess, 20.5ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.9ms
# Speed: 2.2ms preprocess, 23.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.0ms
# Speed: 2.6ms preprocess, 26.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.8ms
# Speed: 2.5ms preprocess, 20.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.0ms
# Speed: 2.6ms preprocess, 26.0ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.3ms
# Speed: 2.9ms preprocess, 22.3ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.3ms
# Speed: 2.8ms preprocess, 25.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.6ms
# Speed: 2.6ms preprocess, 36.6ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.2ms
# Speed: 2.5ms preprocess, 32.2ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.6ms
# Speed: 5.3ms preprocess, 36.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.7ms
# Speed: 2.6ms preprocess, 29.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.9ms
# Speed: 2.6ms preprocess, 19.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.0ms
# Speed: 2.4ms preprocess, 36.0ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.1ms
# Speed: 2.2ms preprocess, 19.1ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.5ms
# Speed: 2.6ms preprocess, 19.5ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.2ms
# Speed: 2.4ms preprocess, 26.2ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.4ms
# Speed: 1.9ms preprocess, 23.4ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 28.3ms
# Speed: 2.7ms preprocess, 28.3ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.0ms
# Speed: 2.7ms preprocess, 25.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 34.3ms
# Speed: 2.9ms preprocess, 34.3ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.0ms
# Speed: 2.8ms preprocess, 22.0ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 34.9ms
# Speed: 2.3ms preprocess, 34.9ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.3ms
# Speed: 2.5ms preprocess, 23.3ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.3ms
# Speed: 2.3ms preprocess, 31.3ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.3ms
# Speed: 2.2ms preprocess, 25.3ms inference, 7.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.0ms
# Speed: 3.1ms preprocess, 27.0ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.9ms
# Speed: 2.8ms preprocess, 23.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 28.1ms
# Speed: 2.5ms preprocess, 28.1ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.4ms
# Speed: 2.5ms preprocess, 25.4ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 13.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.9ms
# Speed: 2.6ms preprocess, 20.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.0ms
# Speed: 2.6ms preprocess, 23.0ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.3ms
# Speed: 2.8ms preprocess, 21.3ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.2ms
# Speed: 2.7ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.4ms
# Speed: 2.8ms preprocess, 24.4ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.3ms
# Speed: 2.2ms preprocess, 21.3ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.2ms
# Speed: 2.3ms preprocess, 27.2ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.1ms
# Speed: 2.2ms preprocess, 24.1ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.9ms
# Speed: 2.3ms preprocess, 25.9ms inference, 8.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.2ms
# Speed: 2.4ms preprocess, 21.2ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.7ms
# Speed: 2.4ms preprocess, 21.7ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.1ms
# Speed: 2.8ms preprocess, 27.1ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.7ms
# Speed: 2.5ms preprocess, 37.7ms inference, 8.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.8ms
# Speed: 2.2ms preprocess, 36.8ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.1ms
# Speed: 2.2ms preprocess, 31.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.5ms
# Speed: 2.0ms preprocess, 24.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.8ms
# Speed: 2.5ms preprocess, 27.8ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.0ms
# Speed: 2.4ms preprocess, 25.0ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.6ms
# Speed: 2.2ms preprocess, 27.6ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.3ms
# Speed: 2.5ms preprocess, 35.3ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.3ms
# Speed: 2.5ms preprocess, 27.3ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.9ms
# Speed: 7.3ms preprocess, 26.9ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.4ms
# Speed: 2.8ms preprocess, 22.4ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.6ms
# Speed: 8.5ms preprocess, 23.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.6ms
# Speed: 3.2ms preprocess, 31.6ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.4ms
# Speed: 2.7ms preprocess, 24.4ms inference, 10.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.4ms
# Speed: 2.5ms preprocess, 22.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.4ms
# Speed: 36.3ms preprocess, 22.4ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.5ms
# Speed: 2.4ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.3ms
# Speed: 2.5ms preprocess, 22.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.7ms
# Speed: 2.4ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.7ms
# Speed: 2.5ms preprocess, 19.7ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.3ms
# Speed: 4.7ms preprocess, 22.3ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 45.1ms
# Speed: 3.2ms preprocess, 45.1ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.3ms
# Speed: 2.3ms preprocess, 22.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.4ms
# Speed: 2.5ms preprocess, 24.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.9ms
# Speed: 2.5ms preprocess, 21.9ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.8ms
# Speed: 2.4ms preprocess, 23.8ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.5ms
# Speed: 2.9ms preprocess, 22.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.4ms
# Speed: 2.8ms preprocess, 36.4ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.8ms
# Speed: 2.5ms preprocess, 20.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.1ms
# Speed: 3.3ms preprocess, 24.1ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.1ms
# Speed: 3.3ms preprocess, 21.1ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 45.0ms
# Speed: 2.6ms preprocess, 45.0ms inference, 8.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 28.5ms
# Speed: 2.7ms preprocess, 28.5ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.1ms
# Speed: 2.6ms preprocess, 29.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.9ms
# Speed: 2.5ms preprocess, 24.9ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.8ms
# Speed: 3.6ms preprocess, 32.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.3ms
# Speed: 2.3ms preprocess, 22.3ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.5ms
# Speed: 2.4ms preprocess, 21.5ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.1ms
# Speed: 2.8ms preprocess, 26.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.7ms
# Speed: 2.9ms preprocess, 32.7ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 38.6ms
# Speed: 3.2ms preprocess, 38.6ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.1ms
# Speed: 2.8ms preprocess, 23.1ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 39.3ms
# Speed: 3.5ms preprocess, 39.3ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.8ms
# Speed: 5.5ms preprocess, 25.8ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 45.6ms
# Speed: 2.4ms preprocess, 45.6ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.9ms
# Speed: 3.1ms preprocess, 20.9ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 30.3ms
# Speed: 2.4ms preprocess, 30.3ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.1ms
# Speed: 2.1ms preprocess, 32.1ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 38.3ms
# Speed: 2.6ms preprocess, 38.3ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 28.9ms
# Speed: 2.8ms preprocess, 28.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.7ms
# Speed: 2.9ms preprocess, 23.7ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.7ms
# Speed: 2.5ms preprocess, 22.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.9ms
# Speed: 3.3ms preprocess, 20.9ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.8ms
# Speed: 3.1ms preprocess, 23.8ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.2ms
# Speed: 2.4ms preprocess, 29.2ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.4ms
# Speed: 2.7ms preprocess, 27.4ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.6ms
# Speed: 2.5ms preprocess, 22.6ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.9ms
# Speed: 2.3ms preprocess, 22.9ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.7ms
# Speed: 2.7ms preprocess, 22.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 38.5ms
# Speed: 2.5ms preprocess, 38.5ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.1ms
# Speed: 2.5ms preprocess, 24.1ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.3ms
# Speed: 3.1ms preprocess, 21.3ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.4ms
# Speed: 2.6ms preprocess, 37.4ms inference, 12.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.7ms
# Speed: 3.0ms preprocess, 20.7ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 30.1ms
# Speed: 3.9ms preprocess, 30.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.5ms
# Speed: 2.3ms preprocess, 20.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 28.2ms
# Speed: 2.5ms preprocess, 28.2ms inference, 11.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 9.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.4ms
# Speed: 2.7ms preprocess, 35.4ms inference, 6.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.4ms
# Speed: 2.6ms preprocess, 25.4ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.5ms
# Speed: 2.5ms preprocess, 22.5ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.0ms
# Speed: 3.6ms preprocess, 20.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.5ms
# Speed: 2.0ms preprocess, 27.5ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.4ms
# Speed: 2.6ms preprocess, 27.4ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.6ms
# Speed: 2.5ms preprocess, 35.6ms inference, 11.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.4ms
# Speed: 3.0ms preprocess, 36.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.1ms
# Speed: 2.5ms preprocess, 19.1ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.8ms
# Speed: 2.4ms preprocess, 22.8ms inference, 8.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.6ms
# Speed: 3.1ms preprocess, 20.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
