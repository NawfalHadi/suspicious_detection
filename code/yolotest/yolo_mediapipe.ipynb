# %% [markdown]
# # Cropped Frame by Yolo, Pose Estimation by Mediapipe

# %%
import mediapipe as mp
from mediapipe.framework.formats import landmark_pb2

from ultralytics import YOLO
import numpy as np
import cv2

mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# --- Configuration ---
FIXED_SIZE = 500
SMALL_SIZE = 150, 150
model = YOLO("../../model/yolo/yolo12n.pt")

# %%
def cropped_frame(frame):
    results = model(frame, classes=[0])
    boxes = results[0].boxes
    plotted_frame = results[0].plot() 

    try:
        if len(boxes) > 0:
            # Get the bounding box coordinates for the first detected object
            x1, y1, x2, y2 = boxes.xyxy[0].cpu().numpy().astype(int)

            cropped_frame = frame[y1:y2, x1:x2]
            crop_h, crop_w = cropped_frame.shape[:2]

            # We want to fit the largest dimension (width or height) to the FIXED_SIZE
            scale = FIXED_SIZE / max(crop_w, crop_h)
            new_w = int(crop_w * scale)
            new_h = int(crop_h * scale)

            # Resize the cropped frame to the new dimensions
            resized_img = cv2.resize(cropped_frame, (new_w, new_h), interpolation=cv2.INTER_AREA)

            # Background frame, that are not filled with boxes
            final_frame = np.full((FIXED_SIZE, FIXED_SIZE, 3), 255, dtype=np.uint8)
            
            # dw and dh are the space left over after placing the image
            dw = FIXED_SIZE - new_w
            dh = FIXED_SIZE - new_h

            # Calculate the starting position (top-left corner) for centering
            top = dh // 2
            bottom = top + new_h
            left = dw // 2
            right = left + new_w

            final_frame[top:bottom, left:right] = resized_img

            return final_frame

        else:
            print("No objects detected in the image.")
    except Exception as e:
        print(f"Error processing frame: {e}")

# %%
cap = cv2.VideoCapture('../../assets/dump/celinguk.mp4')

if not cap.isOpened():
    print("Error opening video file")
else:
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            ret, frame = cap.read()
            if ret:
                frame_cropped = cropped_frame(frame)

                try:
                    # Start Code of mediapipe here
                    frames = cv2.cvtColor(frame_cropped, cv2. COLOR_BGR2RGB)
                    frames.flags.writeable = False
                    
                    results = holistic.process(frames)
                    frames.flags.writeable = True
                    frames = cv2.cvtColor(frame_cropped, cv2. COLOR_RGB2BGR)

                    # Get specific landmarks
                    nose = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.NOSE]
                    wrist_l = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.LEFT_WRIST]
                    elbow_l = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.LEFT_ELBOW]
                    wrist_r = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.RIGHT_WRIST]
                    elbow_r = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.RIGHT_ELBOW]

                    show_landmark_list = landmark_pb2.NormalizedLandmarkList()
                    show_landmark_list.landmark.extend([nose, wrist_l, wrist_r, elbow_l, elbow_r])

                    # Draw landmarks
                    for landmark in show_landmark_list.landmark:
                        x, y = int(landmark.x * frames.shape[1]), int(landmark.y * frames.shape[0])
                        cv2.circle(frames, (x, y), 5, (255, 0, 0), -1)

                    cv2.imshow('Video', frames)
                except Exception as e:
                    print(f"Error displaying frame: {e}")
                
                
                if cv2.waitKey(5) & 0xFF == ord('q'):
                    break
            else:
                break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760668219.915012     859 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1760668219.992764    1299 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.2), renderer: llvmpipe (LLVM 20.1.2, 256 bits)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1760668220.563123    1273 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760668220.914866    1264 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760668220.947267    1267 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760668220.947694    1266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760668220.959187    1271 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760668220.978161    1268 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760668220.991604    1265 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760668220.991703    1273 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 0: 320x640 (no detections), 65.9ms
# Speed: 21.0ms preprocess, 65.9ms inference, 47.1ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 27.2ms
# Speed: 2.9ms preprocess, 27.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 25.8ms
# Speed: 2.8ms preprocess, 25.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 23.6ms
# Speed: 1.6ms preprocess, 23.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 1.6ms preprocess, 20.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 1 person, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 18.1ms postprocess per image at shape (1, 3, 320, 640)
# W0000 00:00:1760668238.364951    1265 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# 0: 320x640 1 person, 23.7ms
# Speed: 1.6ms preprocess, 23.7ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.5ms
# Speed: 1.8ms preprocess, 20.5ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.1ms
# Speed: 1.7ms preprocess, 21.1ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.4ms
# Speed: 2.3ms preprocess, 19.4ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 24.2ms
# Speed: 2.7ms preprocess, 24.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 28.3ms
# Speed: 2.8ms preprocess, 28.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 24.3ms
# Speed: 2.4ms preprocess, 24.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 23.1ms
# Speed: 2.6ms preprocess, 23.1ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 2.4ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 (no detections), 35.9ms
# Speed: 2.7ms preprocess, 35.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 320x640 1 person, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.4ms
# Speed: 2.4ms preprocess, 22.4ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.4ms
# Speed: 1.8ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.0ms
# Speed: 2.6ms preprocess, 21.0ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 39.9ms
# Speed: 1.9ms preprocess, 39.9ms inference, 8.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 1.5ms preprocess, 17.1ms inference, 7.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.7ms
# Speed: 1.8ms preprocess, 26.7ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.8ms
# Speed: 2.8ms preprocess, 23.8ms inference, 8.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.0ms
# Speed: 2.5ms preprocess, 36.0ms inference, 10.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.6ms
# Speed: 1.7ms preprocess, 23.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.9ms
# Speed: 1.8ms preprocess, 21.9ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.8ms
# Speed: 2.2ms preprocess, 20.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 45.2ms
# Speed: 2.2ms preprocess, 45.2ms inference, 8.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.7ms
# Speed: 1.8ms preprocess, 22.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.9ms
# Speed: 2.1ms preprocess, 35.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.5ms
# Speed: 2.0ms preprocess, 22.5ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.3ms
# Speed: 2.1ms preprocess, 20.3ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.4ms
# Speed: 2.1ms preprocess, 27.4ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.3ms
# Speed: 1.6ms preprocess, 16.3ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.7ms
# Speed: 2.0ms preprocess, 22.7ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.3ms
# Speed: 1.5ms preprocess, 19.3ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.4ms
# Speed: 1.4ms preprocess, 16.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 41.2ms
# Speed: 1.8ms preprocess, 41.2ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.8ms
# Speed: 1.7ms preprocess, 16.8ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.3ms
# Speed: 1.6ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.7ms
# Speed: 1.9ms preprocess, 21.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.6ms
# Speed: 1.9ms preprocess, 17.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.2ms
# Speed: 1.6ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.9ms
# Speed: 2.6ms preprocess, 17.9ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.8ms
# Speed: 1.7ms preprocess, 37.8ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.8ms
# Speed: 2.3ms preprocess, 37.8ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 1.7ms preprocess, 16.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.7ms
# Speed: 2.0ms preprocess, 24.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.7ms
# Speed: 1.6ms preprocess, 26.7ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.6ms
# Speed: 1.7ms preprocess, 17.6ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 30.0ms
# Speed: 1.5ms preprocess, 30.0ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.7ms
# Speed: 2.8ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 33.4ms
# Speed: 1.6ms preprocess, 33.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.7ms
# Speed: 2.5ms preprocess, 17.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.5ms
# Speed: 1.9ms preprocess, 35.5ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.9ms
# Speed: 1.7ms preprocess, 17.9ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 32.8ms
# Speed: 1.5ms preprocess, 32.8ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.6ms
# Speed: 2.0ms preprocess, 27.6ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.1ms
# Speed: 1.8ms preprocess, 23.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.4ms
# Speed: 1.8ms preprocess, 17.4ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.4ms
# Speed: 1.7ms preprocess, 17.4ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.3ms
# Speed: 2.6ms preprocess, 20.3ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 2.4ms preprocess, 17.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 6.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.0ms
# Speed: 1.9ms preprocess, 36.0ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.8ms
# Speed: 1.6ms preprocess, 18.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 39.7ms
# Speed: 1.8ms preprocess, 39.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.1ms
# Speed: 2.6ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.6ms
# Speed: 2.0ms preprocess, 21.6ms inference, 4.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.6ms
# Speed: 1.9ms preprocess, 22.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.4ms
# Speed: 2.3ms preprocess, 20.4ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.5ms
# Speed: 1.9ms preprocess, 27.5ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.1ms
# Speed: 2.0ms preprocess, 22.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 27.6ms
# Speed: 2.3ms preprocess, 27.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 34.3ms
# Speed: 2.5ms preprocess, 34.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.5ms
# Speed: 1.9ms preprocess, 25.5ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.9ms
# Speed: 1.6ms preprocess, 24.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.1ms
# Speed: 2.3ms preprocess, 23.1ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.4ms
# Speed: 2.2ms preprocess, 19.4ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.5ms
# Speed: 2.5ms preprocess, 17.5ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.6ms
# Speed: 2.1ms preprocess, 29.6ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.6ms
# Speed: 2.3ms preprocess, 18.6ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.0ms
# Speed: 2.4ms preprocess, 17.0ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 4.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 1.7ms preprocess, 15.6ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.8ms
# Speed: 1.8ms preprocess, 19.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.5ms
# Speed: 2.5ms preprocess, 20.5ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.3ms
# Speed: 1.6ms preprocess, 23.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.4ms
# Speed: 1.8ms preprocess, 31.4ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 17.4ms
# Speed: 1.7ms preprocess, 17.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 17.1ms
# Speed: 1.8ms preprocess, 17.1ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.8ms
# Speed: 1.8ms preprocess, 16.8ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.9ms
# Speed: 2.3ms preprocess, 35.9ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.3ms
# Speed: 1.8ms preprocess, 21.3ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.6ms
# Speed: 1.6ms preprocess, 26.6ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.8ms
# Speed: 2.8ms preprocess, 22.8ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.2ms
# Speed: 2.2ms preprocess, 35.2ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.3ms
# Speed: 2.5ms preprocess, 18.3ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.4ms
# Speed: 2.2ms preprocess, 26.4ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.7ms
# Speed: 1.9ms preprocess, 22.7ms inference, 9.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.0ms
# Speed: 2.2ms preprocess, 17.0ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 5.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.2ms
# Speed: 2.4ms preprocess, 18.2ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.3ms
# Speed: 1.6ms preprocess, 18.3ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.3ms
# Speed: 1.6ms preprocess, 16.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.2ms
# Speed: 1.8ms preprocess, 18.2ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.3ms
# Speed: 1.7ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.5ms
# Speed: 1.7ms preprocess, 26.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.8ms
# Speed: 1.6ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.1ms
# Speed: 2.8ms preprocess, 19.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.8ms
# Speed: 1.8ms preprocess, 31.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.1ms
# Speed: 2.5ms preprocess, 29.1ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.8ms
# Speed: 2.4ms preprocess, 17.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.3ms
# Speed: 1.8ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.8ms
# Speed: 7.2ms preprocess, 17.8ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.7ms
# Speed: 1.6ms preprocess, 19.7ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.9ms
# Speed: 1.5ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.5ms
# Speed: 1.9ms preprocess, 19.5ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.2ms
# Speed: 1.8ms preprocess, 17.2ms inference, 3.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.2ms
# Speed: 1.9ms preprocess, 16.2ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.9ms
# Speed: 2.4ms preprocess, 17.9ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.7ms
# Speed: 2.1ms preprocess, 18.7ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 41.6ms
# Speed: 2.1ms preprocess, 41.6ms inference, 8.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.3ms
# Speed: 2.2ms preprocess, 23.3ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 31.5ms
# Speed: 1.9ms preprocess, 31.5ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 2.6ms preprocess, 16.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.9ms
# Speed: 1.6ms preprocess, 17.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.6ms
# Speed: 1.8ms preprocess, 37.6ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.1ms
# Speed: 2.4ms preprocess, 19.1ms inference, 5.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.2ms
# Speed: 1.6ms preprocess, 17.2ms inference, 5.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 35.5ms
# Speed: 1.9ms preprocess, 35.5ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.4ms
# Speed: 1.7ms preprocess, 36.4ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 37.0ms
# Speed: 1.7ms preprocess, 37.0ms inference, 5.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 22.1ms
# Speed: 1.8ms preprocess, 22.1ms inference, 5.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.4ms
# Speed: 1.6ms preprocess, 26.4ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.1ms
# Speed: 1.5ms preprocess, 18.1ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 26.2ms
# Speed: 2.1ms preprocess, 26.2ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.7ms
# Speed: 2.2ms preprocess, 21.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 34.5ms
# Speed: 2.1ms preprocess, 34.5ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.7ms
# Speed: 1.8ms preprocess, 20.7ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 5.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.8ms
# Speed: 1.6ms preprocess, 17.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.2ms
# Speed: 2.5ms preprocess, 25.2ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.2ms
# Speed: 1.8ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.8ms
# Speed: 1.6ms preprocess, 19.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.0ms
# Speed: 2.0ms preprocess, 19.0ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 8.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.7ms
# Speed: 1.8ms preprocess, 15.7ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.5ms
# Speed: 1.7ms preprocess, 18.5ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.5ms
# Speed: 1.6ms preprocess, 14.5ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.0ms
# Speed: 1.8ms preprocess, 29.0ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.2ms
# Speed: 1.9ms preprocess, 21.2ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.8ms
# Speed: 1.6ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.5ms
# Speed: 1.7ms preprocess, 15.5ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.1ms
# Speed: 1.5ms preprocess, 25.1ms inference, 9.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.4ms
# Speed: 1.8ms preprocess, 15.4ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 39.1ms
# Speed: 2.0ms preprocess, 39.1ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.3ms
# Speed: 2.3ms preprocess, 23.3ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.7ms
# Speed: 2.4ms preprocess, 16.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.8ms
# Speed: 2.4ms preprocess, 16.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.9ms
# Speed: 1.7ms preprocess, 18.9ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.8ms
# Speed: 1.8ms preprocess, 23.8ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 1.7ms preprocess, 16.5ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.8ms
# Speed: 1.7ms preprocess, 15.8ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 5.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.8ms
# Speed: 1.6ms preprocess, 14.8ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.7ms
# Speed: 1.6ms preprocess, 20.7ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 25.4ms
# Speed: 1.9ms preprocess, 25.4ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.7ms
# Speed: 1.8ms preprocess, 15.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 48.3ms
# Speed: 1.6ms preprocess, 48.3ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.8ms
# Speed: 1.8ms preprocess, 14.8ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 1.6ms preprocess, 15.6ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.4ms
# Speed: 1.8ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.4ms
# Speed: 1.8ms preprocess, 23.4ms inference, 4.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.5ms
# Speed: 1.5ms preprocess, 19.5ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.7ms
# Speed: 1.8ms preprocess, 16.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.7ms
# Speed: 1.6ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 34.0ms
# Speed: 1.9ms preprocess, 34.0ms inference, 10.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.3ms
# Speed: 1.8ms preprocess, 14.3ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 3.5ms postprocess per image at shape (1, 3, 320, 640)
