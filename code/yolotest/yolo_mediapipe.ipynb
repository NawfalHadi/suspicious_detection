# %% [markdown]
# # Cropped Frame by Yolo, Pose Estimation by Mediapipe

# %%
import mediapipe as mp
from mediapipe.framework.formats import landmark_pb2

from ultralytics import YOLO
import numpy as np
import cv2

mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# --- Configuration ---
FIXED_SIZE = 640
model = YOLO("../../model/yolo/yolo12n.pt")

# %%
def cropped_frame(frame):
    results = model(frame, classes=[0])
    boxes = results[0].boxes
    plotted_frame = results[0].plot() 

    try:
        if len(boxes) > 0:
            # Get the bounding box coordinates for the first detected object
            x1, y1, x2, y2 = boxes.xyxy[0].cpu().numpy().astype(int)

            cropped_frame = frame[y1:y2, x1:x2]
            crop_h, crop_w = cropped_frame.shape[:2]

            # We want to fit the largest dimension (width or height) to the FIXED_SIZE
            scale = FIXED_SIZE / max(crop_w, crop_h)
            new_w = int(crop_w * scale)
            new_h = int(crop_h * scale)

            # Resize the cropped frame to the new dimensions
            resized_img = cv2.resize(cropped_frame, (new_w, new_h), interpolation=cv2.INTER_AREA)

            # Background frame, that are not filled with boxes
            final_frame = np.full((FIXED_SIZE, FIXED_SIZE, 3), 255, dtype=np.uint8)
            
            # dw and dh are the space left over after placing the image
            dw = FIXED_SIZE - new_w
            dh = FIXED_SIZE - new_h

            # Calculate the starting position (top-left corner) for centering
            top = dh // 2
            bottom = top + new_h
            left = dw // 2
            right = left + new_w

            final_frame[top:bottom, left:right] = resized_img

            return final_frame

        else:
            print("No objects detected in the image.")
    except Exception as e:
        print(f"Error processing frame: {e}")

# %%
cap = cv2.VideoCapture('../../assets/dump/walk.mp4')

if not cap.isOpened():
    print("Error opening video file")
else:
    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
        while cap.isOpened():
            ret, frame = cap.read()
            if ret:
                frame_cropped = cropped_frame(frame)

                try:
                    # Start Code of mediapipe here
                    frames = cv2.cvtColor(frame_cropped, cv2. COLOR_BGR2RGB)
                    frames.flags.writeable = False
                    
                    results = holistic.process(frames)
                    frames.flags.writeable = True
                    frames = cv2.cvtColor(frame_cropped, cv2. COLOR_RGB2BGR)

                    # Get specific landmarks
                    nose = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.NOSE]
                    wrist_l = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.LEFT_WRIST]
                    elbow_l = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.LEFT_ELBOW]
                    wrist_r = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.RIGHT_WRIST]
                    elbow_r = results.pose_landmarks.landmark[mp.solutions.holistic.PoseLandmark.RIGHT_ELBOW]

                    show_landmark_list = landmark_pb2.NormalizedLandmarkList()
                    show_landmark_list.landmark.extend([nose, wrist_l, wrist_r, elbow_l, elbow_r])

                    # Draw landmarks
                    for landmark in show_landmark_list.landmark:
                        x, y = int(landmark.x * frames.shape[1]), int(landmark.y * frames.shape[0])
                        cv2.circle(frames, (x, y), 5, (255, 0, 0), -1)

                    cv2.imshow('Video', frames)
                except Exception as e:
                    print(f"Error displaying frame: {e}")
                
                
                if cv2.waitKey(5) & 0xFF == ord('q'):
                    break
            else:
                break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 60.8ms
# Speed: 3.6ms preprocess, 60.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 3.4ms preprocess, 41.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
# I0000 00:00:1760531286.445234     924 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1760531286.466572   64207 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.2), renderer: llvmpipe (LLVM 20.1.2, 256 bits)
# 0: 384x640 (no detections), 55.7ms
# Speed: 2.9ms preprocess, 55.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 3.7ms preprocess, 49.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 43.9ms
# Speed: 2.1ms preprocess, 43.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 51.4ms
# Speed: 3.2ms preprocess, 51.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 53.7ms
# Speed: 3.6ms preprocess, 53.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 59.5ms
# Speed: 4.2ms preprocess, 59.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 1 person, 55.8ms
# Speed: 3.3ms preprocess, 55.8ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# W0000 00:00:1760531287.080437   64197 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 2.7ms preprocess, 39.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 35.1ms
# Speed: 2.9ms preprocess, 35.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
# W0000 00:00:1760531287.493729   64196 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531287.516658   64199 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531287.517863   64200 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531287.528158   64197 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531287.545299   64198 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531287.571637   64206 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1760531287.578209   64202 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 0: 384x640 (no detections), 46.9ms
# Speed: 5.2ms preprocess, 46.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 33.5ms
# Speed: 2.4ms preprocess, 33.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 28.8ms
# Speed: 3.0ms preprocess, 28.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 33.0ms
# Speed: 2.8ms preprocess, 33.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 2.2ms preprocess, 40.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 35.9ms
# Speed: 2.9ms preprocess, 35.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 (no detections), 35.2ms
# Speed: 2.6ms preprocess, 35.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# No objects detected in the image.
# Error displaying frame: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
#
#
# 0: 384x640 1 person, 32.6ms
# Speed: 2.4ms preprocess, 32.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 384x640 2 persons, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 384x640 2 persons, 28.2ms
# Speed: 2.3ms preprocess, 28.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 384x640 1 person, 34.7ms
# Speed: 3.2ms preprocess, 34.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 384x640 1 person, 33.7ms
# Speed: 2.8ms preprocess, 33.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 384x640 1 person, 41.2ms
# Speed: 3.1ms preprocess, 41.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# Error displaying frame: 'NoneType' object has no attribute 'landmark'
#
# 0: 384x640 1 person, 53.2ms
# Speed: 3.2ms preprocess, 53.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.2ms
# Speed: 3.1ms preprocess, 44.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 44.0ms
# Speed: 2.9ms preprocess, 44.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 31.2ms
# Speed: 2.9ms preprocess, 31.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 29.2ms
# Speed: 2.5ms preprocess, 29.2ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 45.0ms
# Speed: 3.1ms preprocess, 45.0ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 38.6ms
# Speed: 2.9ms preprocess, 38.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.1ms
# Speed: 3.1ms preprocess, 35.1ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 29.4ms
# Speed: 2.8ms preprocess, 29.4ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 31.9ms
# Speed: 3.2ms preprocess, 31.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 28.0ms
# Speed: 2.3ms preprocess, 28.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 27.3ms
# Speed: 2.6ms preprocess, 27.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 26.8ms
# Speed: 2.3ms preprocess, 26.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 27.2ms
# Speed: 3.0ms preprocess, 27.2ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 42.8ms
# Speed: 3.0ms preprocess, 42.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 30.5ms
# Speed: 3.0ms preprocess, 30.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 28.6ms
# Speed: 2.6ms preprocess, 28.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.2ms
# Speed: 2.6ms preprocess, 35.2ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 35.4ms
# Speed: 3.5ms preprocess, 35.4ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 29.5ms
# Speed: 2.2ms preprocess, 29.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 28.4ms
# Speed: 2.3ms preprocess, 28.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 26.6ms
# Speed: 2.3ms preprocess, 26.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 25.8ms
# Speed: 2.4ms preprocess, 25.8ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 34.9ms
# Speed: 3.1ms preprocess, 34.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.0ms
# Speed: 2.6ms preprocess, 32.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 34.0ms
# Speed: 2.7ms preprocess, 34.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.5ms
# Speed: 2.5ms preprocess, 39.5ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 32.2ms
# Speed: 2.3ms preprocess, 32.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 27.6ms
# Speed: 2.4ms preprocess, 27.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 23.2ms
# Speed: 2.9ms preprocess, 23.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 33.9ms
# Speed: 3.2ms preprocess, 33.9ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 26.4ms
# Speed: 2.4ms preprocess, 26.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 26